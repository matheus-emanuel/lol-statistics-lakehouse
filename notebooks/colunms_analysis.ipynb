# %%
import pandas as pd
import os

# %%
file_path = '../data/raw/'
file_name = [f for f in os.listdir(file_path) if f.startswith('2025')]
complete_path = file_path + file_name[0]


df = pd.read_csv(complete_path)

df.head(25)
# Out:
# /tmp/ipykernel_12174/4148473691.py:6: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(complete_path)
#               gameid datacompleteness  url league  year   split  playoffs  \
# 0   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# 1   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# 2   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# 3   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# 4   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# 5   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# 6   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# 7   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# 8   LOLTMNT03_179647         complete  NaN   LFL2  2025  Winter         0
# ...
